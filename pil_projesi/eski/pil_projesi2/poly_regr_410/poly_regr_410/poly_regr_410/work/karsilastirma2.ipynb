# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the data correctly
#df = pd.read_csv("data/karsilastirma2.csv", delimiter=';')
X = np.loadtxt("data/karsilastirma3.txt", usecols=[0], delimiter=',')
y1 = np.loadtxt("data/karsilastirma3.txt", usecols=[1], delimiter=',')
y2 = np.loadtxt("data/karsilastirma3.txt", usecols=[2], delimiter=',')
y3 = np.loadtxt("data/karsilastirma3.txt", usecols=[3], delimiter=',')
y4 = np.loadtxt("data/karsilastirma3.txt", usecols=[4], delimiter=',')

# Remove the " V" and quotes
#df = df.replace(' V', '', regex=True)
#df = df.replace('1e-6', '', regex=True)

# Now convert needed columns to float
#for col in df.columns[1:2]:  # assuming 2nd to 3th columns are your voltage data
 #   df[col] = df[col].astype(float)

# Prepare data for plotting
#X = np.arange(len(df))
#y1 = df.iloc[:,1]
#y2 = df.iloc[:,2]
#y3 = df.iloc[:,3]
#y4 = df.iloc[:,4]
#y5 = df.iloc[:,5]
#print(X)
#print(y1)
#print(y2)

# Plotting
#a = 108   # beginning of prediction number
fig, ax = plt.subplots(1,1,figsize=(12,6))
plt.plot(X, y1, "--", color = "orangered", label="ARIMA")
plt.plot(X, y2, "--", color = "green", label="Poly. Regr.")
plt.plot(X, y3, "--", color = "black", label="AUTO-ARIMA")
plt.plot(X, y4, "--", color = "red", label="LSTM")
#plt.plot(X + a, y4, "--", color = "purple", label="RANSAC")
#plt.plot(X + a, y5, "-+", color = "blue", label="Grad. Desc.", lw=0.5)
plt.title("Comparison - Battery Voltage-Level 732B-5610410", fontsize = 14)
plt.xlabel("Prediction Nr.")
plt.ylabel("10V-Diff.-Voltage Level [1e-6 V]")

plt.legend(loc='upper left')
plt.grid()
plt.show()
